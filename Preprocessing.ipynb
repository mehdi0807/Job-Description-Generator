# %% [markdown]
# # Importing packages and data

# %%
import pandas as pd
import numpy as np
import string

# %%
columns_to_drop = ['index', 'Easy Apply', 'Competitors', 'Revenue', 'Type of ownership', 'Rating']
data = pd.read_csv('Data Scientist Jobs/DataScientist.csv', index_col = 0).drop(columns_to_drop, axis=1)
data
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 3904                                  AWS Data Engineer
# 3905                              Data Analyst â Junior
# 3906                   Security Analytics Data Engineer
# 3907                   Security Analytics Data Engineer
# 3908  Patient Safety Physician or Safety Scientist -...
#
#                    Salary Estimate  \
# 0     $111K-$181K (Glassdoor est.)
# 1     $111K-$181K (Glassdoor est.)
# 2     $111K-$181K (Glassdoor est.)
# 3     $111K-$181K (Glassdoor est.)
# 4     $111K-$181K (Glassdoor est.)
# ...                            ...
# 3904   $55K-$112K (Glassdoor est.)
# 3905   $55K-$112K (Glassdoor est.)
# 3906   $55K-$112K (Glassdoor est.)
# 3907   $55K-$112K (Glassdoor est.)
# 3908   $55K-$112K (Glassdoor est.)
#
#                                         Job Description  \
# 0     ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...
# 1     At Noom, we use scientifically proven methods ...
# 2     Decode_M\n\nhttps://www.decode-m.com/\n\nData ...
# 3     Sapphire Digital seeks a dynamic and driven mi...
# 4     Director, Data Science - (200537)\nDescription...
# ...                                                 ...
# 3904  About Us\n\nTachyon Technologies is a Digital ...
# 3905  Job description\nInterpret data, analyze resul...
# 3906  Job DescriptionThe Security Analytics Data Eng...
# 3907  The Security Analytics Data Engineer will inte...
# 3908  Help us transform patients' lives.\nAt UCB, we...
#
#                                Company Name       Location      Headquarters  \
# 0                               Hopper\n3.5   New York, NY  Montreal, Canada
# 1                              Noom US\n4.5   New York, NY      New York, NY
# 2                                  Decode_M   New York, NY      New York, NY
# 3                     Sapphire Digital\n3.4  Lyndhurst, NJ     Lyndhurst, NJ
# 4           United Entertainment Group\n3.4   New York, NY      New York, NY
# ...                                     ...            ...               ...
# 3904              Tachyon Technologies\n4.4     Dublin, OH        Irving, TX
# 3905  Staffigo Technical Services, LLC\n5.0   Columbus, OH     Woodridge, IL
# 3906                    PDS Tech, Inc.\n3.8     Dublin, OH        Irving, TX
# 3907        Data Resource Technologies\n4.0     Dublin, OH         Omaha, NE
# 3908                               UCB\n3.7     Slough, OH  Brussel, Belgium
#
#                          Size  Founded                   Industry  \
# 0       501 to 1000 employees     2007            Travel Agencies
# 1      1001 to 5000 employees     2008  Health, Beauty, & Fitness
# 2           1 to 50 employees       -1                         -1
# 3        201 to 500 employees     2019                   Internet
# 4         51 to 200 employees     2007    Advertising & Marketing
# ...                       ...      ...                        ...
# 3904     201 to 500 employees     2011                IT Services
# 3905      51 to 200 employees     2008                IT Services
# 3906  5001 to 10000 employees     1977     Staffing & Outsourcing
# 3907        1 to 50 employees       -1                 Accounting
# 3908  5001 to 10000 employees       -1  Biotech & Pharmaceuticals
#
#                          Sector
# 0              Travel & Tourism
# 1             Consumer Services
# 2                            -1
# 3        Information Technology
# 4             Business Services
# ...                         ...
# 3904     Information Technology
# 3905     Information Technology
# 3906          Business Services
# 3907         Accounting & Legal
# 3908  Biotech & Pharmaceuticals
#
# [3909 rows x 10 columns]

# %% [markdown]
# When exploring the dataset I saw that there is too much long descriptions and for computation reasons I want to keep only short descriptions

# %%
# Keeping only descriptions with <=500 words
indexes = []
for index in data.index:
    if len(data.loc[index, 'Job Description'].split())<=350:
        indexes.append(index)

data = data.loc[indexes]
data
# Out:
#                                   Job Title               Salary Estimate  \
# 7           Quantitative Research Associate  $111K-$181K (Glassdoor est.)
# 8                              AI Scientist  $111K-$181K (Glassdoor est.)
# 9                   Quantitative Researcher  $111K-$181K (Glassdoor est.)
# 19                         VP, Data Science  $111K-$181K (Glassdoor est.)
# 22    Quantitative Researcher – Intern (US)  $111K-$181K (Glassdoor est.)
# ...                                     ...                           ...
# 3897                   Senior Data Engineer   $55K-$112K (Glassdoor est.)
# 3901                Principal Data Engineer   $55K-$112K (Glassdoor est.)
# 3902       Columbus Data Science Tutor Jobs   $55K-$112K (Glassdoor est.)
# 3904                      AWS Data Engineer   $55K-$112K (Glassdoor est.)
# 3905                  Data Analyst â Junior   $55K-$112K (Glassdoor est.)
#
#                                         Job Description  \
# 7     Seeking a quant to work with senior researcher...
# 8     Paige is a software company helping pathologis...
# 9     About the Position\n\n\nAt Jane Street, we con...
# 19    We are looking for a VP, Data Science to lead ...
# 22    Job Description\n\nQuantitative Researchers at...
# ...                                                 ...
# 3897  Job Responsibility:\nBased on business strateg...
# 3901  ComResource is looking for a Principal Data En...
# 3902  #Columbus Data Science Tutor Jobs\n\nVarsity T...
# 3904  About Us\n\nTachyon Technologies is a Digital ...
# 3905  Job description\nInterpret data, analyze resul...
#
#                                Company Name      Location     Headquarters  \
# 7                    Enlightenment Research  New York, NY     New York, NY
# 8                                Paige\n5.0  New York, NY     New York, NY
# 9                          Jane Street\n4.8  New York, NY     New York, NY
# 19                          7Park Data\n3.9  New York, NY     New York, NY
# 22                  Citadel Securities\n4.1  New York, NY      Chicago, IL
# ...                                     ...           ...              ...
# 3897                         Kognetics\n3.6   Gahanna, OH     New York, NY
# 3901                       ComResource\n4.6  Columbus, OH     Columbus, OH
# 3902                    Varsity Tutors\n4.2  Columbus, OH  Saint Louis, MO
# 3904              Tachyon Technologies\n4.4    Dublin, OH       Irving, TX
# 3905  Staffigo Technical Services, LLC\n5.0  Columbus, OH    Woodridge, IL
#
#                        Size  Founded                                 Industry  \
# 7         1 to 50 employees       -1                                       -1
# 8         1 to 50 employees     2018  Enterprise Software & Network Solutions
# 9     501 to 1000 employees     2000    Investment Banking & Asset Management
# 19      51 to 200 employees     2012                   Research & Development
# 22     201 to 500 employees     2002                       Brokerage Services
# ...                     ...      ...                                      ...
# 3897      1 to 50 employees       -1                                       -1
# 3901   201 to 500 employees     1991                              IT Services
# 3902   201 to 500 employees     2007                                 Internet
# 3904   201 to 500 employees     2011                              IT Services
# 3905    51 to 200 employees     2008                              IT Services
#
#                       Sector
# 7                         -1
# 8     Information Technology
# 9                    Finance
# 19         Business Services
# 22                   Finance
# ...                      ...
# 3897                      -1
# 3901  Information Technology
# 3902  Information Technology
# 3904  Information Technology
# 3905  Information Technology
#
# [1296 rows x 10 columns]

# %% [markdown]
# I can see that the `-1` value represent the null value

# %%
data.replace('-1', np.nan, inplace=True)
data.replace(-1, np.nan, inplace=True)

# %%
data.isna().sum()
# Out:
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Company Name         0
# Location             0
# Headquarters       122
# Size               117
# Founded            482
# Industry           268
# Sector             268
# dtype: int64

# %%
data['Founded'] = data['Founded'].fillna(data['Founded'].max())
data['Headquarters'] = data['Headquarters'].fillna(data['Location'])

# %%
# Check how much rows has at least one null value
len(data) - len(data.dropna())
# Out:
# 268

# %%
# Keeping only samples with no null values to create the best prompts
data.dropna(inplace=True)
data.shape
# Out:
# (1028, 10)

# %% [markdown]
# I noticed that there is some anomalies in the `Company Name` and `Salary Estimate` columns

# %%
data['Company Name'] = data['Company Name'].str.replace('\n', '').str.translate(str.maketrans('', '', string.digits))
data['Salary Estimate'] = data['Salary Estimate'].str.split('(').str.get(0)
data
# Out:
#                                               Job Title Salary Estimate  \
# 8                                          AI Scientist    $111K-$181K
# 9                               Quantitative Researcher    $111K-$181K
# 19                                     VP, Data Science    $111K-$181K
# 22                Quantitative Researcher – Intern (US)    $111K-$181K
# 23    Senior Data Engineer (Healthcare Domain experi...    $111K-$181K
# ...                                                 ...             ...
# 3894  JPSC-7975 - Data Analyst Lead- Columbus, OH (L...     $55K-$112K
# 3901                            Principal Data Engineer     $55K-$112K
# 3902                   Columbus Data Science Tutor Jobs     $55K-$112K
# 3904                                  AWS Data Engineer     $55K-$112K
# 3905                              Data Analyst â Junior     $55K-$112K
#
#                                         Job Description  \
# 8     Paige is a software company helping pathologis...
# 9     About the Position\n\n\nAt Jane Street, we con...
# 19    We are looking for a VP, Data Science to lead ...
# 22    Job Description\n\nQuantitative Researchers at...
# 23    Key Responsibilities\n\n- Architect, build, an...
# ...                                                 ...
# 3894  Overview\n\nRole: Data Analyst Lead – Informat...
# 3901  ComResource is looking for a Principal Data En...
# 3902  #Columbus Data Science Tutor Jobs\n\nVarsity T...
# 3904  About Us\n\nTachyon Technologies is a Digital ...
# 3905  Job description\nInterpret data, analyze resul...
#
#                            Company Name      Location      Headquarters  \
# 8                                Paige.  New York, NY      New York, NY
# 9                          Jane Street.  New York, NY      New York, NY
# 19                           Park Data.  New York, NY      New York, NY
# 22                  Citadel Securities.  New York, NY       Chicago, IL
# 23              Enterprise Integration.  New York, NY  Jacksonville, FL
# ...                                 ...           ...               ...
# 3894        Avani Technology Solutions.  Columbus, OH     Rochester, NY
# 3901                       ComResource.  Columbus, OH      Columbus, OH
# 3902                    Varsity Tutors.  Columbus, OH   Saint Louis, MO
# 3904              Tachyon Technologies.    Dublin, OH        Irving, TX
# 3905  Staffigo Technical Services, LLC.  Columbus, OH     Woodridge, IL
#
#                        Size  Founded                                 Industry  \
# 8         1 to 50 employees   2018.0  Enterprise Software & Network Solutions
# 9     501 to 1000 employees   2000.0    Investment Banking & Asset Management
# 19      51 to 200 employees   2012.0                   Research & Development
# 22     201 to 500 employees   2002.0                       Brokerage Services
# 23      51 to 200 employees   1998.0                              IT Services
# ...                     ...      ...                                      ...
# 3894  501 to 1000 employees   2008.0                              IT Services
# 3901   201 to 500 employees   1991.0                              IT Services
# 3902   201 to 500 employees   2007.0                                 Internet
# 3904   201 to 500 employees   2011.0                              IT Services
# 3905    51 to 200 employees   2008.0                              IT Services
#
#                       Sector
# 8     Information Technology
# 9                    Finance
# 19         Business Services
# 22                   Finance
# 23    Information Technology
# ...                      ...
# 3894  Information Technology
# 3901  Information Technology
# 3902  Information Technology
# 3904  Information Technology
# 3905  Information Technology
#
# [1028 rows x 10 columns]

# %%
data.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Company Name',
#        'Location', 'Headquarters', 'Size', 'Founded', 'Industry', 'Sector'],
#       dtype='object')

# %% [markdown]
# # Prompt Engineering
# For modeling reasons I opted for engineering prompts which the answers are the descriptions

# %%
# Example of feature engineering
job_title = data.iloc[1]['Job Title']
company_name = data.iloc[1]['Company Name']
year = data.iloc[1]['Founded']
size = data.iloc[1]['Size']
industry = data.iloc[1]['Industry']
sector = data.iloc[1]['Sector']
location = data.iloc[1]['Location']
headquarter = data.iloc[1]['Headquarters']
salary_estimate = data.iloc[1]['Salary Estimate']
print('The prompt:')
print(f'Write a job description for {job_title} role proposed by "{company_name}", a company founded on {year} that has now a size of {size} and works on {industry} industry in the {sector} sector. The job proposed is in {location} meanwhile the headquarter of the company is in {headquarter}. The salary estimate is {salary_estimate}')
print('-'*127)
print('')
print('The job description:')
print(data.iloc[1]['Job Description'])
# Out:
# The prompt:
# Write a job description for Quantitative Researcher role proposed by "Jane Street.", a company founded on 2000.0 that has now a size of 501 to 1000 employees and works on Investment Banking & Asset Management industry in the Finance sector. The job proposed is in New York, NY meanwhile the headquarter of the company is in New York, NY. The salary estimate is $111K-$181K
# -------------------------------------------------------------------------------------------------------------------------------
#
# The job description:
# About the Position
#
#
# At Jane Street, we consider trading and programming to be two ends of a continuum. As both a trading firm and a tech firm, we have room for people who love to trade, people who love to program, and people everywhere in between. Nearly all of our traders write code, and many of our developers trade. The role you carve out for yourself will be largely dependent on your strengths and the types of problems you enjoy thinking about.
#
# Researchers at Jane Street are responsible for building models, strategies, and systems that price and trade a variety of financial instruments. As a mix of the trading and software developer roles, this work involves many things: analyzing large datasets, building and testing models, creating new trading strategies, and writing the code that implements them.
#
# About You
# Be able to apply logical and mathematical thinking to all kinds of problems. Asking great questions is more important than knowing all the answers.
# Write great code. We mostly write in OCaml, so you should want to learn functional programming if you don't already have experience with it.
# Have good taste in research.The problems we work on rarely have clean, definitive answers. You should be comfortable pushing in new and unknown directions while maintaining clarity of purpose.
# Think and communicate precisely and openly. We believe great solutions come from the interaction between diverse groups of people across the firm.

# %%
# Creating prompt for every sample
data['Prompt'] = [' ' for i in range(len(data))]
for index in data.index:
    job_title = data.loc[index,'Job Title']
    company_name = data.loc[index,'Company Name']
    year = data.loc[index,'Founded']
    size = data.loc[index,'Size']
    industry = data.loc[index,'Industry']
    sector = data.loc[index,'Sector']
    location = data.loc[index,'Location']
    headquarter = data.loc[index,'Headquarters']
    salary_estimate = data.loc[index,'Salary Estimate']
    data.loc[index, 'Prompt'] = f'Write a job description for {job_title} role proposed by "{company_name}", a company founded on {year} that has now a size of {size} and works on {industry} industry in the {sector} sector. The job proposed is in {location} meanwhile the headquarter of the company is in {headquarter}. The salary estimate is {salary_estimate}'
    
data['Prompt']
# Out:
# 8       Write a job description for AI Scientist role ...
# 9       Write a job description for Quantitative Resea...
# 19      Write a job description for VP, Data Science r...
# 22      Write a job description for Quantitative Resea...
# 23      Write a job description for Senior Data Engine...
#                               ...
# 3894    Write a job description for JPSC-7975 - Data A...
# 3901    Write a job description for Principal Data Eng...
# 3902    Write a job description for Columbus Data Scie...
# 3904    Write a job description for AWS Data Engineer ...
# 3905    Write a job description for Data Analyst â Jun...
# Name: Prompt, Length: 1028, dtype: object

# %%
# Modeling my dataframe into prompts and targets
data['Target'] = data['Job Description']
data = data[['Prompt', 'Target']]
data
# Out:
#                                                  Prompt  \
# 8     Write a job description for AI Scientist role ...
# 9     Write a job description for Quantitative Resea...
# 19    Write a job description for VP, Data Science r...
# 22    Write a job description for Quantitative Resea...
# 23    Write a job description for Senior Data Engine...
# ...                                                 ...
# 3894  Write a job description for JPSC-7975 - Data A...
# 3901  Write a job description for Principal Data Eng...
# 3902  Write a job description for Columbus Data Scie...
# 3904  Write a job description for AWS Data Engineer ...
# 3905  Write a job description for Data Analyst â Jun...
#
#                                                  Target
# 8     Paige is a software company helping pathologis...
# 9     About the Position\n\n\nAt Jane Street, we con...
# 19    We are looking for a VP, Data Science to lead ...
# 22    Job Description\n\nQuantitative Researchers at...
# 23    Key Responsibilities\n\n- Architect, build, an...
# ...                                                 ...
# 3894  Overview\n\nRole: Data Analyst Lead – Informat...
# 3901  ComResource is looking for a Principal Data En...
# 3902  #Columbus Data Science Tutor Jobs\n\nVarsity T...
# 3904  About Us\n\nTachyon Technologies is a Digital ...
# 3905  Job description\nInterpret data, analyze resul...
#
# [1028 rows x 2 columns]

# %%
data.to_csv('Data Scientist Jobs/Processed_data.csv', index=False)
